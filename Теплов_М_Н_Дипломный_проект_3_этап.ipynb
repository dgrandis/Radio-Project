# %% [markdown]
# # **Задание подготовки к диплому**
#
# Ответом будет текстовое описание того, каким образом обработаны данные  и подготовлены для работы с нейронкой. Если возможно,  продемонстрируйте пример (табличка).

# %% [markdown]
# # **Подготовка даных**

# %% [markdown]
# Все подготоленные данные из **2 этапа** требуется разделить на **две** большие группы:
#   - Музыкальные композиции
#   - Реклама, речь

# %% [markdown]
# Для этого воспользовался программой **Audacity** для того чтобы из архивной записи радиоэфира нарезать нужные треки.

# %% [markdown]
# ## 1. Выбираем нужную запись радиоэфира

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 2. Вырезаем нужный фрагмент с музыкальной композицией, речью или рекламой

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 3. Общий вид

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 4. Сохраняем в файл в формате mp3

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 5. Сбор аудиофрагментов в одной папке

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Получилось вырезать из радиоэфиров нужные данные. Файлы с номерами от **1 до 308**.
# И есть непосредственно скаченные записи рекламы и разговоров.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Такие длинные названия для того чтобы подготовить данные для подачи в нейронную сеть не требуются. Поэтому переименуем все файлы по порядку.

# %%
# Для этой операции воспользуемся данным кодом

path = f'F:\\Дипломный проект\\Speech\\'
count = 1
for i in os.listdir(path):
    os.rename(path + i, path + str(count) + '.mp3')
    count += 1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Аналогично поступим с папкой **Music**. В которой находятся музыкальные композиции

# %% [markdown]
# # Итог

# %% [markdown]
# Получились две папки с аудиофрагментами
#   - **Music** (Музыкальные композиции)
#   - **Speech** (Разговоры, реклама)

# %% [markdown]
# Теперь эти данные можно формировать в векторы с ответами в формате **ohe** и подавать в нейронную сеть для обучения.
