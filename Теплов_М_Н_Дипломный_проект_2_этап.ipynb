# %% [markdown]
# # **Задание подготовки к диплому**
#
# Ответом будет текстовое описание того, какая база собрана, сколько примеров. Если возможно, покажите пример из базы (например: картинки, тексты)

# %% [markdown]
# # **Сбор базы**

# %% [markdown]
# ![Все радиостанции.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# В основу базы для обучений нейронной сети вошли недавние архивные записи эфиров радиостанций такие как:
#   - Наше радио
#   - DFM
#   - Русское радио
#   - Maximum
#   - Радио Дача
#   - Радио NRJ
#   - Europa plus
#   - Хит FM
#   Всего: **9,33Гб** (Около 100 часов)
#
# Так же записи разговоров на радиостанциях:
#   - Гатчинское радио
#   - Жуковское радио
#   - Новый канал
#   - Мозовая,9
#   - Радио Карелии
#   - Логос
#   - Звезда
#   - Шансон
#   - Старый город Елабуга
#   - Чудо радио
#   - Стихотвореня ТМ-радио
#   - и пр.
#   Всего: **2,1Гб** (Около 30 часов)
#
# Реклама различного содержания **162Мб** (Около 1,5 часа)

# %% [markdown]
# Всего записей радиоэфира и рекламы **11,5ГБ**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# База для обучения получилась очень большая.
#
# И так как радиостанции вещают каждый день, то можно увеличивать базу и дообучать нейронную сеть довольно часто.
#
# Для парсинга данных и первичного обучения нейронной сети такой объем базы считаю достаточным.

# %% [markdown]
# Спасибо за внимание.
